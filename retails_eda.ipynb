# %%
## EDA on Retails Sales DataSet and Mcdonald_Menu with Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Data Loading and Cleaning: Load the retail sales dataset.

# %%
df_retail= pd.read_csv("retail_sales_dataset.csv")
df_menu= pd.read_csv("menu.csv")

# %%
df_retail.head() # Display The first 5 rows
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df_menu.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
## Row & Column

print("Retail Data Shape:", df_retail.shape)
print("McDonald's Data Shape:", df_menu.shape)
# Out:
# Retail Data Shape: (1000, 9)
# McDonald's Data Shape: (260, 24)

# %%
## Info

df_retail.info()
print("\n \n ")
df_menu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
# ...

# %%
## Check the total Nulls Value in the Table
print("Retails Nulls:", df_retail.isnull().sum())
print("\n")
print("McDonald Nulls",df_menu.isnull().sum())
# Out:
# Retails Nulls: Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64
#
#
# McDonald Nulls Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# ...

# %%
## Duplicate Value
print("Retails Duplicate",df_retail.duplicated().sum())
print("\n")
print("McDonald Duplicate",df_menu.duplicated().sum())
# Out:
# Retails Duplicate 0
#
#
# McDonald Duplicate 0

# %% [markdown]
# 2. Descriptive Statistics: Calculate basic statistics (mean, median, mode, standard deviation).

# %%
print("Retail Sales Summary Statistics")
d1=df_retail.describe()
print(d1,"\n")

Median_Age=df_retail['Age'].median()
print("Median Age=",Median_Age)
# Out:
# Retail Sales Summary Statistics
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000
#
# Median Age= 42.0

# %%
print("McDonald Menu Summary Statistics")
df_menu.describe().T
# Out:
# McDonald Menu Summary Statistics
#                                count        mean         std  min      25%  \
# Calories                       260.0  368.269231  240.269886  0.0  210.000
# Calories from Fat              260.0  127.096154  127.875914  0.0   20.000
# Total Fat                      260.0   14.165385   14.205998  0.0    2.375
# Total Fat (% Daily Value)      260.0   21.815385   21.885199  0.0    3.750
# Saturated Fat                  260.0    6.007692    5.321873  0.0    1.000
# Saturated Fat (% Daily Value)  260.0   29.965385   26.639209  0.0    4.750
# Trans Fat                      260.0    0.203846    0.429133  0.0    0.000
# Cholesterol                    260.0   54.942308   87.269257  0.0    5.000
# Cholesterol (% Daily Value)    260.0   18.392308   29.091653  0.0    2.000
# Sodium                         260.0  495.750000  577.026323  0.0  107.500
# Sodium (% Daily Value)         260.0   20.676923   24.034954  0.0    4.750
# ...

# %%
x=df_menu.select_dtypes(include=np.number).columns

stat_menu={
    col: {
        'Means': df_menu[col].mean(),
        'Median': df_menu[col].median(),
        'Mode':df_menu[col].mode().iloc[0],
        'Std Dev':df_menu[col].std()
    }
    for col in x 
}
y=pd.DataFrame(stat_menu).T
y.round(2)
# Out:
#                                 Means  Median   Mode  Std Dev
# Calories                       368.27   340.0    0.0   240.27
# Calories from Fat              127.10   100.0    0.0   127.88
# Total Fat                       14.17    11.0    0.0    14.21
# Total Fat (% Daily Value)       21.82    17.0    0.0    21.89
# Saturated Fat                    6.01     5.0    0.0     5.32
# Saturated Fat (% Daily Value)   29.97    24.0    0.0    26.64
# Trans Fat                        0.20     0.0    0.0     0.43
# Cholesterol                     54.94    35.0    0.0    87.27
# Cholesterol (% Daily Value)     18.39    11.0    0.0    29.09
# Sodium                         495.75   190.0  180.0   577.03
# Sodium (% Daily Value)          20.68     8.0    6.0    24.03
# Carbohydrates                   47.35    44.0    0.0    28.25
# Carbohydrates (% Daily Value)   15.78    15.0   14.0     9.42
# Dietary Fiber                    1.63     1.0    1.0     1.57
# ...

# %% [markdown]
# 3.Time Series Analysis: Analyze sales trends over time using time series techniques.

# %%
df_retail.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df_menu.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df_retail['Date']
# Out:
# 0      2023-11-24
# 1      2023-02-27
# 2      2023-01-13
# 3      2023-05-21
# 4      2023-05-06
#           ...
# 995    2023-05-16
# 996    2023-11-17
# 997    2023-10-29
# 998    2023-12-05
# 999    2023-04-12
# Name: Date, Length: 1000, dtype: object

# %%
df_retail['Date']=pd.to_datetime(df_retail['Date'])

# %%
df_retail.set_index('Date',inplace=True)
df_retail.sort_index(inplace=True)

# %%
df_retail.head()
# Out:
#             Transaction ID Customer ID  Gender  Age Product Category  \
# Date
# 2023-01-01             522     CUST522    Male   46           Beauty
# 2023-01-01             180     CUST180    Male   41         Clothing
# 2023-01-01             559     CUST559  Female   40         Clothing
# 2023-01-02             303     CUST303    Male   19      Electronics
# 2023-01-02             979     CUST979  Female   19           Beauty
#
#             Quantity  Price per Unit  Total Amount
# Date
# 2023-01-01         3             500          1500
# 2023-01-01         3             300           900
# 2023-01-01         4             300          1200
# 2023-01-02         3              30            90
# 2023-01-02         1              25            25

# %%
## Plotting Monthly Sales Trend

monthly_sales = df_retail['Total Amount'].resample('ME').sum()

plt.figure(figsize=(12,6))
plt.plot(monthly_sales, marker='o', linestyle='-', color='blue')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales Amount')
plt.grid(True)
plt.show()

# %%
monthly_Quantity = df_retail['Quantity'].resample('ME').sum()

plt.figure(figsize=(12,6))
plt.plot(monthly_Quantity, marker='o', linestyle='--', color='red')
plt.title('Monthly Quantity Trend')
plt.xlabel('Month')
plt.ylabel('Total Qunatity')
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Customer and Product Analysis: Analyze customer demographics and purchasing behavior.

# %%
# Count of Male vs Female
sns.countplot(data=df_retail, x='Gender', hue='Gender', palette='Set2')
plt.title("Customer Gender Distribution")
plt.ylabel("Number of Customers")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df_retail, x='Age', kde=True, bins=20,  color='red')
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
# Most Popular Product

plt.figure(figsize=(10,6))
sns.countplot(data=df_retail, x='Product Category', hue='Product Category', palette='cool', legend=False)
plt.title("Top product Categories (by Quantity Sold)")
plt.xlabel("Count")
plt.ylabel("Product Category")
plt.show()

# %%
# Total Sales By Product Category
plt.figure(figsize=(10,6))
sns.barplot(y='Total Amount', x='Product Category', hue='Product Category', data=df_retail, palette="Set3")
plt.title("Total Sales by product category")
plt.ylabel("Total Amount($)")
plt.xlabel("Product Category")
plt.show()

# %%
### Menu.csv
# Counts of Items by Category

plt.figure(figsize=(15,6))
sns.countplot(data=df_menu,y='Category', hue='Category',palette='Set2')
plt.title("Number of Items per Category")
plt.xlabel=("Count")
plt.ylabel("Category")
plt.show()

# %%
# Average Calories per Food Category
avg_cal = df_menu.groupby('Category')['Calories'].mean()
plt.figure(figsize=(15,6))
sns.barplot(y=avg_cal.index, x=avg_cal.values,hue=avg_cal.values, palette="Set3" , legend=False)
plt.title("Average Calories per Food Category")

plt.show()

# %%
#Top 10 Highest calorie Items
top_10 = df_menu[['Item', 'Calories']].sort_values(by='Calories', ascending=False).head(10)
plt.figure(figsize=(10,6))
sns.barplot(data=top_10, y='Item', x='Calories', palette='magma')
plt.title("Top 10 Highest Calorie Items")
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_33196\404556997.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10, y='Item', x='Calories', palette='magma')

# %% [markdown]
# 5.Visualization: Present insights through bar charts, line plots, and heatmaps.

# %%
## Retail Dataset
# Calculate correlation matrix
corr=  df_retail[['Age','Quantity','Price per Unit','Total Amount']].corr()
plt.figure(figsize=(16,6))
sns.heatmap(data=corr,annot=True, cmap='coolwarm',fmt=".2f")
plt.title("Correlation Heatmap (Retail Dataset)")
plt.show()

# %%
# Sales By product Category by Pie Chart

Sales = df_retail.groupby('Product Category')['Total Amount'].sum()
plt.figure(figsize=(16,6))
plt.pie(Sales, labels=Sales.index, colors=sns.color_palette('magma'), autopct='%1.1f%%')
plt.title("Sales Share by product Category")
plt.show()

# %%
# Gender Vs Average Spend

Avg_Spn=df_retail.groupby('Gender')['Total Amount'].mean()
print(Avg_Spn)
plt.figure(figsize=(6,5))
Avg_Spn.plot(kind='bar',color=['hotpink','royalblue'])
plt.title("Gender Vs Average Spend")
plt.show()
# Out:
# Gender
# Female    456.549020
# Male      455.428571
# Name: Total Amount, dtype: float64

# %%
## Menu.csv
# Correlation Heatmap
cols=['Calories','Saturated Fat','Cholesterol','Sodium','Carbohydrates','Dietary Fiber','Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
       'Calcium (% Daily Value)', 'Iron (% Daily Value)']
plt.figure(figsize=(16,6))
sns.heatmap(df_menu[cols].corr(),annot=True,cmap='coolwarm')
plt.title("Nutrient Correlation HeatMap")
plt.show()

# %%
df_menu.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
# Item Distribution By Category by PieChart
Itm_dis=df_menu.groupby('Category')['Item'].count()
plt.figure(figsize=(10,6))
Itm_dis.plot(kind='pie', colors=sns.color_palette('Set2'),autopct='%1.1f%%')
plt.title("Item Distribution By Category")
plt.show()

# %%
## Category Vs Avg Protein by Bar Chart

avg_protein = df_menu.groupby('Category')['Protein'].mean().sort_values()
plt.figure(figsize=(16,6))
avg_protein.plot(kind='barh', color=sns.color_palette('magma'))
plt.title("Category Vs Avg Protein")
plt.show()

# %%
df_menu.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# 6. Recommendations: Provide actionable recommendations based on the EDA.
#
#    a. Retails Sales :
#    Since both men and women shop almost equally,Gender
#    Female    456.549020
#    Male      455.428571
#    So,design gender-neutral promotions and discount that appeal to both.
#    Promote Electronics during festive seaons or salary days, when people are more likely to buy high-ticket items.
#    Launch Fashion Deals mid month, target cothing buers with flash sales and combo packs.
#    Use Social Media Ads to Push Beaty Products.
#
#    b.Mcdonald's Menu
#    Highlight Nutritionally Balanced Items(low Calories, Low Sodium,High Protein)
#    Add Visible nutrition labels this builds transparency and trust
#    As you see from the above data Chicken and fish has most protein and a items sales distribution of 10.4%.By doing so you can raise the sales of these type of food.
#    Beverages,coffee,Smoothies are hold the maximum stake of item distribution   (50+)%.So you can add offers and discount which helps you increase your sales.
